# %% [markdown]
# # Project: cleanning - [candy data]
# ### this notebook is for educational purpose . in this notebook we will do some cleanning
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">wrangling</a></li>
#
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# ### Dataset Description
#
# > i will go through candy data 2017 , this data has :
# - Internal_ID
# - Q1-Going Out?: Are you actually going trick or treating yourself? "has values `Yes or No`"
# - Q2-Gender: It has four different options, `Femal ,Male ,Other ,I'd rather not say`
# - Q3-Age: Numerical field
# - Q4-Country: Text Field, but users have written their own version of the names. Example, for America, there are entries such as USA, us, US, America so we should consider that while cleanning
# - Q5-State/Province: Text Field, but users have written their own version of the names. Same as the country data.
# - Q6-Joy Or Despair: All kinds of chocolate bars are the questions with three distinct options to choose from (Joy, Meh, Despair).
# - Q7-Joy Other: Text Field to write items not included above that give you JOY. Lots of missing values.
# - Q8-Despair Other: Text Field ti write items not included above that give you DESPAIR. Lots of missing values.
# - Q9-Other Comments: Text Field. Lots of missing values.
# - Q10-Dress: Binary field. Missing values present
# - Unnamed: 113
# - Q11-Day: Binary Answer Field. Missing values present

# %% [markdown]
# # 1- import packages and load data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  




df = pd.read_excel("candyhierarchy2017.xlsx")
# Out:
# c:\Users\User\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
df.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# ...

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
#
#
# ### General Properties

# %% [markdown]
# # 2- show some general properties for the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Columns: 120 entries, Internal ID to Click Coordinates (x, y)
# dtypes: float64(4), int64(1), object(115)
# memory usage: 2.3+ MB

# %%
df.describe()
# Out:
#         Internal ID  Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  \
# count  2.460000e+03                     85.0                1362.0
# mean   9.028016e+07                      1.0                   1.0
# std    7.435532e+03                      0.0                   0.0
# min    9.025877e+07                      1.0                   1.0
# 25%    9.027520e+07                      1.0                   1.0
# 50%    9.027780e+07                      1.0                   1.0
# 75%    9.028242e+07                      1.0                   1.0
# max    9.031480e+07                      1.0                   1.0
#
#        Q12: MEDIA [ESPN]  Q12: MEDIA [Yahoo]
# count               99.0                67.0
# mean                 1.0                 1.0
# std                  0.0                 0.0
# min                  1.0                 1.0
# 25%                  1.0                 1.0
# 50%                  1.0                 1.0
# ...

# %% [markdown]
# # 3- write summary about what you get form the above functions
# > #### tips : this summary can be about : if there is any missing values , if there a wrong data type , if there a wrong range of values , ....

# %% [markdown]
# RangeIndex: 2460 entries, 0 to 2459
#
# Columns: 120 entries, Internal ID to Click Coordinates (x, y)
#
# dtypes: float64(4), int64(1), object(115)

# %% [markdown]
# # cleaning

# %% [markdown]
# ### 4- drop all the useless columns and  rows with too much NaN ,
# > tip : useless columns can be like `Internal ID`and can be also columns with too much NaN
# - rename columns for easy access

# %%
df.drop(['Internal ID' ,'Q7: JOY OTHER', 'Q8: DESPAIR OTHER' ,'Unnamed: 113' , 'Q12: MEDIA [Daily Dish]' 
         , 'Q12: MEDIA [ESPN]' , 'Q12: MEDIA [Yahoo]' , 'Q12: MEDIA [Science]' 
         ,'Click Coordinates (x, y)' , 'Q9: OTHER COMMENTS'  ] , axis=1 , inplace=True)

# %%
for col in df.columns:
    new_col_name = col.replace('Q6 | ','')
    df.rename(columns={col : new_col_name}, inplace=True)

# %%
df.rename(columns={'Q1: GOING OUT?':'GOING OUT','Q2: GENDER':'GENDER','Q3: AGE':'AGE','Q4: COUNTRY':'COUNTRY',
                   'Q5: STATE, PROVINCE, COUNTY, ETC':'AREA','Q10: DRESS':'DRESS',
                   'Q11: DAY':'DAY'},inplace=True)

# %%
df.head(5)
# Out:
#   GOING OUT GENDER  AGE COUNTRY      AREA 100 Grand Bar  \
# 0       NaN    NaN  NaN     NaN       NaN           NaN
# 1        No   Male   44    USA         NM           MEH
# 2       NaN   Male   49     USA  Virginia           NaN
# 3        No   Male   40      us        or           MEH
# 4        No   Male   23     usa  exton pa           JOY
#
#   Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Any full-sized candy bar Black Jacks Bonkers (the candy)  ... Trail Mix  \
# 0                      NaN         NaN                 NaN  ...       NaN
# 1                      JOY         MEH             DESPAIR  ...   DESPAIR
# ...

# %% [markdown]
# ### 5 - clean `going out` column
# > tip : you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df['GOING OUT'].unique()
# Out:
# array([nan, 'No', 'Yes'], dtype=object)

# %%
df['GOING OUT'] = df['GOING OUT'].fillna('NOT SPECIFIED')

# %%
df.head(5)
# Out:
#        GOING OUT GENDER  AGE COUNTRY      AREA 100 Grand Bar  \
# 0  NOT SPECIFIED    NaN  NaN     NaN       NaN           NaN
# 1             No   Male   44    USA         NM           MEH
# 2  NOT SPECIFIED   Male   49     USA  Virginia           NaN
# 3             No   Male   40      us        or           MEH
# 4             No   Male   23     usa  exton pa           JOY
#
#   Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Any full-sized candy bar Black Jacks Bonkers (the candy)  ... Trail Mix  \
# 0                      NaN         NaN                 NaN  ...       NaN
# 1                      JOY         MEH             DESPAIR  ...   DESPAIR
# ...

# %% [markdown]
# ### 6 - clean ` gender` column
# > tip : you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df['GENDER'].unique()
# Out:
# array([nan, 'Male', 'Female', "I'd rather not say", 'Other'], dtype=object)

# %%
df['GENDER'] = df['GENDER'].fillna("I'd rather not say")

# %%
df['GENDER'].replace("Other", "I'd rather not say", inplace=True)

# %%
df.head(5)
# Out:
#        GOING OUT              GENDER  AGE COUNTRY      AREA 100 Grand Bar  \
# 0  NOT SPECIFIED  I'd rather not say  NaN     NaN       NaN           NaN
# 1             No                Male   44    USA         NM           MEH
# 2  NOT SPECIFIED                Male   49     USA  Virginia           NaN
# 3             No                Male   40      us        or           MEH
# 4             No                Male   23     usa  exton pa           JOY
#
#   Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Any full-sized candy bar Black Jacks Bonkers (the candy)  ... Trail Mix  \
# 0                      NaN         NaN                 NaN  ...       NaN
# ...

# %% [markdown]
# ### 7 - clean ` age` column
# > tip : note the type of age column , and NaN values
#  - try to use `to_numeric`
#  - tip : you should choose which best value to put in place of these NaNs ( mean, median, ....etc)

# %%
df['AGE'].isna().sum()
# Out:
# 84

# %%
df['AGE'] = pd.to_numeric(df['AGE'], errors='coerce')

# %%
df['AGE'].fillna(df['AGE'].mean(), inplace=True)

# %%
df['AGE'] = df['AGE'].astype(int)

# %%
df.loc[df['AGE'] > 100 ] = np.nan

# %%
df.head()
# Out:
#        GOING OUT              GENDER   AGE COUNTRY      AREA 100 Grand Bar  \
# 0  NOT SPECIFIED  I'd rather not say  42.0     NaN       NaN           NaN
# 1             No                Male  44.0    USA         NM           MEH
# 2  NOT SPECIFIED                Male  49.0     USA  Virginia           NaN
# 3             No                Male  40.0      us        or           MEH
# 4             No                Male  23.0     usa  exton pa           JOY
#
#   Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Any full-sized candy bar Black Jacks Bonkers (the candy)  ... Trail Mix  \
# 0                      NaN         NaN                 NaN  ...       NaN
# ...

# %% [markdown]
# ### 8 - clean ` country` column
# > tip : note that country column has country names with different writing ways
#   - use fuzzywuzzy to deal with this problem
#   - you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df['COUNTRY'].unique()
# Out:
# array([nan, 'USA ', 'USA', 'us', 'usa', 'canada', 'Canada', 'Us', 'US',
#        'Murica', 'United States', 'uk', 'United Kingdom', 'united states',
#        'Usa', 'United States ', 'United staes',
#        'United States of America', 'UAE', 'England', 'UK', 'canada ',
#        'Mexico', 'United states', 'u.s.a.', 'USAUSAUSA', 'america', 35,
#        'france', 'United States of America ', 'U.S.A.', 'finland',
#        'unhinged states', 'Canada ', 'united states of america',
#        'US of A', 'Unites States', 'The United States', 'North Carolina ',
#        'Unied States', 'Netherlands', 'germany', 'Europe', 'Earth', 'U S',
#        'u.s.', 'U.K. ', 'Costa Rica', 'The United States of America',
#        'unite states', 'U.S.', 46, 'cascadia', 'Australia',
#        'insanity lately', 'Greece', 'USA? Hard to tell anymore..',
#        "'merica", 'usas', 'Pittsburgh', 45, 'United State', 32, 'France',
#        'australia', 'Can', 'Canae', 'New York', 'Trumpistan', 'Ireland',
# ...

# %%
df['COUNTRY'].value_counts()
# Out:
# COUNTRY
# USA                  699
# United States        497
# usa                  217
# Canada               178
# Usa                  139
#                     ...
# Korea                  1
# United Sates           1
# unhinged states        1
# Trumpistan             1
# Fear and Loathing      1
# Name: count, Length: 126, dtype: int64

# %%
df['COUNTRY'] = df['COUNTRY'].str.upper()
df['COUNTRY'] = df['COUNTRY'].str.strip()

# %%
mapping = {'US':'USA','UNITED STATES':'USA','UNITED STATES OF AMERICA':'USA','U.S.':'USA',
           'U.S.A.':'USA','AMERICA':'USA','UNITES STATES':'USA','US OF A':'USA','THE UNITED STATES':'USA',
           'UNITED STATED':'USA','UNITED STATE':'USA','UNITED STSTES':'USA','UNITED KINGDOM':'UK'}
df['COUNTRY'] = df['COUNTRY'].replace(mapping)

# %%
bad_values = df['COUNTRY'].value_counts()[df['COUNTRY'].value_counts().values < 2].index
final = df['COUNTRY'].isin(bad_values)

# %%
df['COUNTRY'].loc[final] = 'USA'
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8844\1404828291.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['COUNTRY'].loc[final] = 'USA'

# %%
df['COUNTRY'].fillna('USA',inplace=True)

# %%
df['COUNTRY'].value_counts()
# Out:
# COUNTRY
# USA            2150
# CANADA          223
# UK               32
# GERMANY          10
# AUSTRALIA         7
# NETHERLANDS       6
# JAPAN             5
# SCOTLAND          5
# MEXICO            4
# IRELAND           4
# FRANCE            3
# SWITZERLAND       3
# DENMARK           2
# CHINA             2
# HONG KONG         2
# SWEDEN            2
# Name: count, dtype: int64

# %% [markdown]
# ### 9 - clean ` area` column
# > tip : area column has the same problem as country columns , but looking at all it's unique values may give us another way to deal with it rather than try to fix it

# %%
df['AREA'].unique()
# Out:
# array([nan, 'NM', 'Virginia', 'or', 'exton pa', 'Colorado ', 'ontario',
#        'Ontario', 'Wa', 'Quebec', 'NY', 'California', 'Texas', 'NEW YORK',
#        'CO', 'IN', 'MN', 'aberdeenshire', 'Alberta', 'Wisconsin, 53705',
#        'RI', 'NC', 'Scotland', 'minnesota', 'Michigan', 'Florida',
#        'New Jersey', 'VA', 'Colorado', 'Los Angeles, California', 'CA',
#        'New York ', 'Chicago, Illinois', 'Nj', 'Wisconsin', 'Minnesota ',
#        'London', 'mn', 'TEXAS', 'Illinois', 'District of Columbia',
#        'Washington', 'Massachusetts ', 'OR', 'Montana', 'New York',
#        'massachusetts', 'Abu Dhabi', 'TX', 'Arizona', 'Dc', 'yukon',
#        'Pennsylvania ', 'MD', 'Ohio', 'Alberta ', 'OXFORDSHIRE', 'DC',
#        'Iowa', 'Mn', 'TN', 'BC', 'Maryland', 'MI', 'Wisconsin ', 'alaska',
#        'Ny', 'Colorado, Jefferson county ', 'Louisiana', 'pa',
#        'CO, Larimer County', 'Nebraska ', 'Oregon', 'UT', 'ny',
# ...

# %%
df.drop('AREA', axis=1, inplace=True)

# %%
df.head(5)
# Out:
#        GOING OUT              GENDER   AGE COUNTRY 100 Grand Bar  \
# 0  NOT SPECIFIED  I'd rather not say  42.0     USA           NaN
# 1             No                Male  44.0     USA           MEH
# 2  NOT SPECIFIED                Male  49.0     USA           NaN
# 3             No                Male  40.0     USA           MEH
# 4             No                Male  23.0     USA           JOY
#
#   Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Any full-sized candy bar Black Jacks Bonkers (the candy)  \
# 0                      NaN         NaN                 NaN
# 1                      JOY         MEH             DESPAIR
# ...

# %% [markdown]
# ### 10 - clean ` Q6` columns
# >- tip : Q6 has all kinds of chocolate bars and questions with three distinct options to choose from (Joy, Meh, Despair).
# - so all the column that has Q6 is a candy name , so you should go through all these column and you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df.iloc[:,4:106].isnull().sum()
# Out:
# 100 Grand Bar                                                                        750
# Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)    737
# Any full-sized candy bar                                                             675
# Black Jacks                                                                          961
# Bonkers (the candy)                                                                  995
#                                                                                     ...
# Vials of pure high fructose corn syrup, for main-lining into your vein               795
# Vicodin                                                                              792
# Whatchamacallit Bars                                                                 826
# White Bread                                                                          760
# Whole Wheat anything                                                                 750
# ...

# %%
df = df.drop(df[df.iloc[:,4:106].isnull().all(axis=1)].index)

# %%
df.iloc[:,4:106].isnull().sum()
# Out:
# 100 Grand Bar                                                                         89
# Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)     76
# Any full-sized candy bar                                                              14
# Black Jacks                                                                          300
# Bonkers (the candy)                                                                  334
#                                                                                     ...
# Vials of pure high fructose corn syrup, for main-lining into your vein               134
# Vicodin                                                                              131
# Whatchamacallit Bars                                                                 165
# White Bread                                                                           99
# Whole Wheat anything                                                                  89
# ...

# %%
values = (df.iloc[:,4:106].isnull().sum()/(df.shape[0]))*100
values = pd.DataFrame(values,columns=['percentage'])

# %%
values.head(5)
# Out:
#                                                     percentage
# 100 Grand Bar                                         4.947193
# Anonymous brown globs that come in black and or...    4.224569
# Any full-sized candy bar                              0.778210
# Black Jacks                                          16.675931
# Bonkers (the candy)                                  18.565870

# %%
values['percentage'].sort_values(ascending=False)[0:15]
# Out:
# JoyJoy (Mit Iodine!)                           20.455809
# Maynards                                       20.344636
# Reggie Jackson Bar                             19.788772
# Bonkers (the board game)                       19.344080
# Sweetums (a friend to diabetes)                19.121734
# Bonkers (the candy)                            18.565870
# Black Jacks                                    16.675931
# Chick-o-Sticks (we don’t know what that is)    16.008894
# Kinder Happy Hippo                             15.953307
# Senior Mints                                   15.786548
# Abstained from M&M'ing.                        15.786548
# Take 5                                         14.396887
# Smarties (Commonwealth)                        13.507504
# Spotted Dick                                   12.451362
# Goo Goo Clusters                               12.284603
# Name: percentage, dtype: float64

# %%
missing = (df.iloc[:,4:106].isnull().sum()/(df.shape[0]))*100
columns_to_drop = missing[missing > 15].index

# %%
columns_to_drop
# Out:
# Index(['Black Jacks', 'Bonkers (the candy)', 'Bonkers (the board game)',
#        'Chick-o-Sticks (we don’t know what that is)', 'JoyJoy (Mit Iodine!)',
#        'Senior Mints', 'Kinder Happy Hippo', 'Maynards',
#        'Abstained from M&M'ing.', 'Reggie Jackson Bar',
#        'Sweetums (a friend to diabetes)'],
#       dtype='object')

# %%
filtered_df = df.drop(columns= columns_to_drop)

# %%
filtered_df.iloc[:,4:106].isnull().sum()
# Out:
# 100 Grand Bar                                                                         89
# Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)     76
# Any full-sized candy bar                                                              14
# Bottle Caps                                                                          107
# Box'o'Raisins                                                                         30
#                                                                                     ...
# White Bread                                                                           99
# Whole Wheat anything                                                                  89
# York Peppermint Patties                                                               48
# DRESS                                                                                 90
# DAY                                                                                   70
# ...

# %%
filtered_df['100 Grand Bar'].value_counts(sort=True,ascending=False).index[0]
# Out:
# 'JOY'

# %%
filtered_df.shape
# Out:
# (1799, 98)

# %%
for col in filtered_df.iloc[:,4:96]:
    filtered_df[col] = filtered_df[col].fillna(filtered_df[col].value_counts(sort=True,ascending=False).index[0])

# %%
filtered_df.iloc[:,4:96].isnull().sum().sum()
# Out:
# 0

# %%
data = []
for col in filtered_df.iloc[:,4:96]:
    num_joy = df[col].value_counts()['JOY']
    num_meh = df[col].value_counts()['MEH']
    num_despaire = df[col].value_counts()['DESPAIR']
    data.append({'Candy': col, 'JOY': num_joy, 'MEH': num_meh, 'DESPAIR': num_despaire})
data = pd.DataFrame(data)
data = data.set_index(data['Candy'])

# %%
data.head()
# Out:
#                                                                                                 Candy  \
# Candy
# 100 Grand Bar                                                                           100 Grand Bar
# Anonymous brown globs that come in black and or...  Anonymous brown globs that come in black and o...
# Any full-sized candy bar                                                     Any full-sized candy bar
# Bottle Caps                                                                               Bottle Caps
# Box'o'Raisins                                                                           Box'o'Raisins
#
#                                                      JOY  MEH  DESPAIR
# Candy
# 100 Grand Bar                                        873  752       85
# Anonymous brown globs that come in black and or...   175  460     1088
# Any full-sized candy bar                            1556  212       17
# ...

# %%
data['JOY'].sort_values(ascending=False)[0:10]
# Out:
# Candy
# Any full-sized candy bar                1556
# Reese’s Peanut Butter Cups              1496
# Kit Kat                                 1445
# Cash, or other forms of legal tender    1438
# Twix                                    1411
# Snickers                                1396
# Tolberone something or other            1318
# Peanut M&M’s                            1289
# Lindt Truffle                           1275
# Nestle Crunch                           1186
# Name: JOY, dtype: int64

# %%
filtered_df['Butterfinger'].value_counts()['JOY']
# Out:
# 1198

# %%
for col in filtered_df.iloc[:,4:96]:
    filtered_df[col].value_counts()

# %% [markdown]
# ### 11 - clean ` dress` column
# >tip : you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df['DRESS'].unique()
# Out:
# array(['White and gold', nan, 'Blue and black'], dtype=object)

# %%
df['DRESS']=df['DRESS'].fillna('Prefer not to say')

# %%
df.head(5)
# Out:
#   GOING OUT GENDER   AGE COUNTRY 100 Grand Bar  \
# 1        No   Male  44.0     USA           MEH
# 3        No   Male  40.0     USA           MEH
# 4        No   Male  23.0     USA           JOY
# 5        No   Male  42.0     USA           JOY
# 7        No   Male  33.0  CANADA           JOY
#
#   Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                            DESPAIR
# 3                                            DESPAIR
# 4                                            DESPAIR
# 5                                            DESPAIR
# 7                                            DESPAIR
#
#   Any full-sized candy bar Black Jacks Bonkers (the candy)  \
# 1                      JOY         MEH             DESPAIR
# 3                      JOY         MEH                 MEH
# 4                      JOY     DESPAIR                 MEH
# 5                      JOY         NaN                 NaN
# ...

# %% [markdown]
# ### 12 - clean ` day` column
# >tip : you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df['DAY'].unique()
# Out:
# array(['Sunday', 'Friday', nan], dtype=object)

# %%
df['DAY']=df['DAY'].fillna('Other')

# %%
df.head(5)
# Out:
#   GOING OUT GENDER   AGE COUNTRY 100 Grand Bar  \
# 1        No   Male  44.0     USA           MEH
# 3        No   Male  40.0     USA           MEH
# 4        No   Male  23.0     USA           JOY
# 5        No   Male  42.0     USA           JOY
# 7        No   Male  33.0  CANADA           JOY
#
#   Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                            DESPAIR
# 3                                            DESPAIR
# 4                                            DESPAIR
# 5                                            DESPAIR
# 7                                            DESPAIR
#
#   Any full-sized candy bar Black Jacks Bonkers (the candy)  \
# 1                      JOY         MEH             DESPAIR
# 3                      JOY         MEH                 MEH
# 4                      JOY     DESPAIR                 MEH
# 5                      JOY         NaN                 NaN
# ...

# %% [markdown]
# ### 13 - check
# > after finish cleaning you should make sure your data is clean and that :
# - there is no wrong data type
# - there is no NaN values
# - all the column are cleaing and ready for the next step `EDA`

# %%
df.isna().sum()
# Out:
# GOING OUT                   0
# GENDER                      0
# AGE                         0
# COUNTRY                     0
# 100 Grand Bar              89
#                            ..
# White Bread                99
# Whole Wheat anything       89
# York Peppermint Patties    48
# DRESS                       0
# DAY                         0
# Length: 109, dtype: int64
